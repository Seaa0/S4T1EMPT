# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

dataset = pd.read_csv("preprocessedDataset.csv")
sns.pairplot(dataset, y_vars=['sleep duration','quality of sleep'], x_vars=dataset.columns.drop('sleep duration','quality of sleep'))
